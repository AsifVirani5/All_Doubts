# %%
import pandas as pd
import numpy as np
import json

# %%
# Read the dataset
df = pd.read_excel("C:/Users/460379/Python Projects ineuron/Python_SQL_MongoDB_Assignments/data fsds/Dress Sales.xlsx")
print(df)
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
# Find the information of the Dataset dress sales
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Dress_ID             500 non-null    int64
#  1   29/8/2013            500 non-null    int64
#  2   31/8/2013            500 non-null    int64
#  3   2013-02-09 00:00:00  500 non-null    int64
#  4   2013-04-09 00:00:00  500 non-null    int64
#  5   2013-06-09 00:00:00  500 non-null    int64
#  6   2013-08-09 00:00:00  500 non-null    int64
#  7   2013-10-09 00:00:00  500 non-null    int64
#  8   2013-12-09 00:00:00  500 non-null    object
#  9   14/9/2013            500 non-null    object
#  10  16/9/2013            500 non-null    object
#  11  18/9/2013            500 non-null    object
#  12  20/9/2013            500 non-null    object
#  13  22/9/2013            500 non-null    object
#  14  24/9/2013            500 non-null    int64
# ...

# %%
# Find if the datasets contains any null values
df.isnull()
df.head(100)
# Out:
#       Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0   1006032852       2114       2274                 2491
# 1   1212192089        151        275                  570
# 2   1190380701          6          7                    7
# 3    966005983       1005       1128                 1326
# 4    876339541        996       1175                 1304
# ..         ...        ...        ...                  ...
# 95  1027818824          1          1                    2
# 96   891103323          8         12                   14
# 97  1166855026          7          8                   10
# 98  1023850025        113        123                  168
# 99   805438829        628        638                  684
#
#     2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                  2660                 2727                 2887
# 1                   750                  813                 1066
# 2                     7                    8                    8
# ...

# %%
# Check how many columns has Nan values
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# Dress_ID                 0
# 29/8/2013                0
# 31/8/2013                0
# 2013-02-09 00:00:00      0
# 2013-04-09 00:00:00      0
# 2013-06-09 00:00:00      0
# 2013-08-09 00:00:00      0
# 2013-10-09 00:00:00      0
# 2013-12-09 00:00:00      0
# 14/9/2013                0
# 16/9/2013                0
# 18/9/2013                0
# 20/9/2013                0
# 22/9/2013                0
# 24/9/2013                0
# 26/9/2013              237
# 28/9/2013                0
# 30/9/2013              273
# 2013-02-10 00:00:00    275
# 2013-04-10 00:00:00    274
# 2013-06-10 00:00:00      0
# 2010-08-10 00:00:00    271
# 2013-10-10 00:00:00    271
# 2013-12-10 00:00:00      0
# dtype: int64

# %%
#Replace NaN values using numpy
df['26/9/2013'] = df['26/9/2013'].replace(np.nan, 0)
df['30/9/2013'] = df['30/9/2013'].replace(np.nan, 0)
df['10/2/2013'] = df['10/2/2013'].replace(np.nan, 0)
df['10/4/2013'] = df['10/4/2013'].replace(np.nan, 0)
df['10/8/2010'] = df['10/8/2010'].replace(np.nan, 0)
df['10/10/2013'] = df['10/10/2013'].replace(np.nan, 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '10/2/2013'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
