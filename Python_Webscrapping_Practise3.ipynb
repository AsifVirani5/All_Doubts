# %%
        
        box = bigboxes[5]
        productLink = "https://www.flipkart.com" + box.div.a['href']
        
        #print(commentboxes)
        #Commenthead = commentboxes[5].div.find_all('p', {"class": "_2-N8zT"})[0].text
        #custComment = commentboxes[5].div.div.find_all("div", {"class": ""})[0].text
        #Name = commentboxes[5].div.div.find_all("p", {"class":"_2sc7ZR _2V5EHH"})[0].text
        #Rating = commentboxes[5].div.div.div.div.text
        filename = searchString + ".csv"
        fw = open(filename, "w")
        headers = "Product, Customer Name, Rating, Heading, Comment \n"
        fw.write(headers)
        reviews = []
        for commentbox in commentboxes:
            name = commentbox.div.div.find_all("p", {"class": "_2sc7ZR _2V5EHH"})[0].text
            rating = commentbox.div.div.div.div.text
            Commenthead = commentbox.div.find_all('p', {"class": "_2-N8zT"})[0].text
            custComment = commentbox.div.div.find_all("div", {"class": ""})[0].text
            mydict = {"Product": searchString, "Customer Name": name, "Rating": rating, "Heading": Commenthead,
                      "Comment": custComment}
            reviews.append(mydict)
        return render_template('results.html', reviews=reviews[0:(len(reviews) - 1)])
    else:
        return render_template('index.html')

# %%
from flask import Flask, request, render_template
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
flipkart_URL = "https://www.flipkart.com/search?q=" + "iphone12"
uClient = uReq(flipkart_URL)
flipkartPage = uClient.read()
uClient.close()
flipkart_html = bs(flipkartPage, "html.parser")
bigboxes = flipkart_html.find_all('div', {"class": "_1AtVbE col-12-12"})
print(bigboxes)
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone12&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy
# ...

# %%
box = bigboxes[5]
productLink = "https://www.flipkart.com" + box.div.a['href']

# %%
print(productLink)
# Out:
# https://www.flipkart.com/apple-iphone-12-black-256-gb/p/itm68421fa1c1121?pid=MOBFWBYZ7CR9FRHZ&lid=LSTMOBFWBYZ7CR9FRHZIALAIL&marketplace=FLIPKART&q=iphone12&store=tyy%2F4io&srno=s_1_4&otracker=search&fm=organic&iid=2cd2898d-d810-46be-844b-305d21388538.MOBFWBYZ7CR9FRHZ.SEARCH&ppt=None&ppn=None&ssid=vdcqgf2zww0000001662959347713&qH=ad588135f239b88b

# %%
prodRes = requests.get(productLink)
prodRes.encoding = 'utf-8'
prod_html = bs(prodRes.text, "html.parser")
commentboxes = prod_html.find_all('div', {"class": "_16PBlm"})

# %%
print(commentboxes)
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Perfect product!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">The brand is very trustworthy and i got genuine pice at a very low cost.I ordered the green one and trust me the colour was amazing.All the colours but specifically green and purple are nice for look.Thanks to flipkart❤️</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202110/blobio-imr-202110_9d4e3389a1aa4ab995f2c65293c439b4.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202110/blobio-imr-202110_f6dfd41bd70143f9955accb2bda478d0.jpeg?q=90), url(d
# ...

# %%
Name = commentboxes[7].div.find_all("p", {"class": "_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Suddha Ram boro'

# %%
custComment = commentboxes[5].find_all("div", {"class": ""})[0].text
custComment
# Out:
# 'Excellent product worth for every penny, writing this review after using 7 days, earlier was using iPhone 6Plus now on iPhone 12 😍, faster then anything this else.Excellent Picture quality.Just loved it.!!READ MORE'

# %%
Rating = commentboxes[2].div.div.div.div.text
Rating
# Out:
# '5'

# %%
Commenthead = commentboxes[9].find_all('p', {"class": "_2-N8zT"})[0].text
Commenthead
# Out:
# 'Highly recommended'

# %%
len(commentboxes)
# Out:
# 11

# %%
reviews = []
for i in range(len(commentboxes)):
    name = commentboxes[i].div.find_all("p", {"class": "_2sc7ZR _2V5EHH"})[0].text
    rating = commentboxes[i].div.div.div.div.text
    Commenthead = commentboxes[i].find_all('p', {"class": "_2-N8zT"})[0].text
    custComment = commentboxes[i].find_all("div", {"class": ""})[0].text
    mydict = {"Customer Name": name, "Rating": rating, "Heading": Commenthead,
                      "Comment": custComment}
    reviews.append(mydict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [67], in <cell line: 2>()
#       1 reviews = []
#       2 for i in range(len(commentboxes)):
# ----> 3     name = commentboxes[i].div.find_all("p", {"class": "_2sc7ZR _2V5EHH"})[0].text
#       4     rating = commentboxes[i].div.div.div.div.text
#       5     Commenthead = commentboxes[i].find_all('p', {"class": "_2-N8zT"})[0].text
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
